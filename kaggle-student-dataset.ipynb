# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('/kaggle/input/student-habits-vs-academic-performance/student_habits_performance.csv')

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df['parental_education_level'].isnull().sum()
# Out:
# 91

# %%
df['parental_education_level']
# Out:
# 0           Master
# 1      High School
# 2      High School
# 3           Master
# 4           Master
#           ...
# 995    High School
# 996    High School
# 997       Bachelor
# 998       Bachelor
# 999       Bachelor
# Name: parental_education_level, Length: 1000, dtype: object

# %%
df[df['parental_education_level'].isnull()]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 10       S1010   19  Female                  4.6                 3.7
# 33       S1033   18  Female                  4.0                 0.9
# 47       S1047   23  Female                  2.5                 2.9
# 74       S1074   21  Female                  2.3                 1.0
# 93       S1093   22    Male                  4.1                 2.5
# ..         ...  ...     ...                  ...                 ...
# 921      S1921   23  Female                  4.4                 2.7
# 925      S1925   19   Other                  1.7                 2.9
# 939      S1939   18  Female                  4.7                 3.2
# 945      S1945   23    Male                  6.0                 2.9
# 967      S1967   22    Male                  5.2                 4.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df['parental_education_level'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', nan], dtype=object)

# %%
df['parental_education_level']=df['parental_education_level'].map({np.nan:0, 'High School':1,'Bachelor':2,'Master':3})

# %%
df['parental_education_level'].head()
# Out:
# 0    3
# 1    1
# 2    1
# 3    3
# 4    3
# Name: parental_education_level, dtype: int64

# %%
df['parental_education_level'].unique()
# Out:
# array([3, 1, 2, 0])

# %%
df['parental_education_level']=df['parental_education_level'].astype(int)

# %%
df['parental_education_level'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: parental_education_level
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   int64
# dtypes: int64(1)
# memory usage: 7.9 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['student_id'].head()
# Out:
# 0    S1000
# 1    S1001
# 2    S1002
# 3    S1003
# 4    S1004
# Name: student_id, dtype: object

# %%
df['student_id']=df['student_id'].str.replace('S','',case=False,regex=False)

# %%
df['student_id'].head(-1)
# Out:
# 0      1000
# 1      1001
# 2      1002
# 3      1003
# 4      1004
#        ...
# 994    1994
# 995    1995
# 996    1996
# 997    1997
# 998    1998
# Name: student_id, Length: 999, dtype: object

# %%
df['student_id']=df['student_id'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['gender'].head()
# Out:
# 0    Female
# 1    Female
# 2      Male
# 3    Female
# 4    Female
# Name: gender, dtype: object

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
encoder=LabelEncoder()

# %%
df['gender']=encoder.fit_transform(df['gender'])

# %%
df['gender'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: gender, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   int64
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['study_hours_per_day'].head()
# Out:
# 0    0.0
# 1    6.9
# 2    1.4
# 3    1.0
# 4    5.0
# Name: study_hours_per_day, dtype: float64

# %%
df['study_hours_per_day'].isnull().sum()
# Out:
# 0

# %%
df['study_hours_per_day']=df['study_hours_per_day'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   int64
#  3   study_hours_per_day            1000 non-null   int64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['social_media_hours']=df['social_media_hours'].astype(int)

# %%
df['netflix_hours']=df['netflix_hours'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   int64
#  3   study_hours_per_day            1000 non-null   int64
#  4   social_media_hours             1000 non-null   int64
#  5   netflix_hours                  1000 non-null   int64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['part_time_job'].head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: part_time_job, dtype: object

# %%
df['part_time_job'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['part_time_job']=encoder.fit_transform(df['part_time_job'])

# %%
df['part_time_job'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: part_time_job, dtype: int64

# %%
df['part_time_job'].unique()
# Out:
# array([0, 1])

# %%
df['part_time_job'].astype(int)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    1
# 997    0
# 998    1
# 999    0
# Name: part_time_job, Length: 1000, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   int64
#  3   study_hours_per_day            1000 non-null   int64
#  4   social_media_hours             1000 non-null   int64
#  5   netflix_hours                  1000 non-null   int64
#  6   part_time_job                  1000 non-null   int64
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['attendance_percentage'].head()
# Out:
# 0    85.0
# 1    97.3
# 2    94.8
# 3    71.0
# 4    90.9
# Name: attendance_percentage, dtype: float64

# %%
df['attendance_percentage'].astype(int)
# Out:
# 0       85
# 1       97
# 2       94
# 3       71
# 4       90
#       ...
# 995     77
# 996     86
# 997     61
# 998    100
# 999     89
# Name: attendance_percentage, Length: 1000, dtype: int64

# %%
df['sleep_hours'].head()
# Out:
# 0    8.0
# 1    4.6
# 2    8.0
# 3    9.2
# 4    4.9
# Name: sleep_hours, dtype: float64

# %%
df['diet_quality'].head()
# Out:
# 0    Fair
# 1    Good
# 2    Poor
# 3    Poor
# 4    Fair
# Name: diet_quality, dtype: object

# %%
df['diet_quality'].unique()
# Out:
# array(['Fair', 'Good', 'Poor'], dtype=object)

# %%
df['diet_quality']=encoder.fit_transform(df['diet_quality'])

# %%
df['diet_quality'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    2
# 4    0
# Name: diet_quality, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   int64
#  3   study_hours_per_day            1000 non-null   int64
#  4   social_media_hours             1000 non-null   int64
#  5   netflix_hours                  1000 non-null   int64
#  6   part_time_job                  1000 non-null   int64
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   int64
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['internet_quality'].head()
# Out:
# 0    Average
# 1    Average
# 2       Poor
# 3       Good
# 4       Good
# Name: internet_quality, dtype: object

# %%
df['internet_quality'].unique()
# Out:
# array(['Average', 'Poor', 'Good'], dtype=object)

# %%
df['internet_quality']=encoder.fit_transform(df['internet_quality'])

# %%
df['internet_quality'].head()
# Out:
# 0    0
# 1    0
# 2    2
# 3    1
# 4    1
# Name: internet_quality, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   int64
#  3   study_hours_per_day            1000 non-null   int64
#  4   social_media_hours             1000 non-null   int64
#  5   netflix_hours                  1000 non-null   int64
#  6   part_time_job                  1000 non-null   int64
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   int64
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['extracurricular_participation'].head()
# Out:
# 0    Yes
# 1     No
# 2     No
# 3    Yes
# 4     No
# Name: extracurricular_participation, dtype: object

# %%
df['extracurricular_participation'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['extracurricular_participation']=encoder.fit_transform(df['extracurricular_participation'])

# %%
df['extracurricular_participation'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: extracurricular_participation, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   int64
#  3   study_hours_per_day            1000 non-null   int64
#  4   social_media_hours             1000 non-null   int64
#  5   netflix_hours                  1000 non-null   int64
#  6   part_time_job                  1000 non-null   int64
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   int64
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...

# %%
df['exam_score'].head()
# Out:
# 0     56.2
# 1    100.0
# 2     34.3
# 3     26.8
# 4     66.4
# Name: exam_score, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   int64
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   int64
#  3   study_hours_per_day            1000 non-null   int64
#  4   social_media_hours             1000 non-null   int64
#  5   netflix_hours                  1000 non-null   int64
#  6   part_time_job                  1000 non-null   int64
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   int64
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   int64
# ...
